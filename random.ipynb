# %%
from matplotlib import pyplot as plt
import math
import numpy as np

# %%
np.random.uniform()
# Out:
# 0.8442402683639872

# %%
data = [np.random.uniform() for _ in range(1000)]
plt.hist(data)
plt.show()

# %%
data = [np.random.normal() for _ in range(1000)]
plt.hist(data)
plt.show()
